# %%
import pandas as pd

#Importação das Bases
produtos_df = pd.read_csv('Contoso - Cadastro Produtos.csv', sep = ';', encoding='latin1')
vendas_df = pd.read_csv('Contoso - Vendas - 2017.csv', sep = ';', encoding='latin1')
lojas_df = pd.read_csv('Contoso - Lojas.csv', sep = ';', encoding='latin1')
clientes_df = pd.read_csv('Contoso - Clientes.csv', sep = ';', encoding='latin1')

#Renomeando Colunas
try:
    produtos_df.rename(columns={'ÿNome do Produto' : 'Nome do Produto'}, inplace = True)
    lojas_df.rename(columns={'ÿID Loja' : 'ID Loja'}, inplace = True)
    clientes_df.rename(columns={'ÿID Cliente' : 'ID Cliente'}, inplace = True)
except:
    print("Ja foi alterado")

#Pegando apenas as colunas necessárias
try:
    clientes_df = clientes_df[['ID Cliente', 'E-mail']]
    produtos_df = produtos_df[['ID Produto', 'Nome do Produto']]
    lojas_df = lojas_df[['ID Loja', 'Nome da Loja']]
except:
    print("Alteração de colunas já feitas")

#Juntando bases
try:
    vendas_df = vendas_df.merge(produtos_df, on = 'ID Produto')
    vendas_df = vendas_df.merge(lojas_df, on = 'ID Loja')
    vendas_df = vendas_df.merge(clientes_df, on = 'ID Cliente').rename(columns={'E-mail' : 'E-mail do Cliente'})
except:
    print("Merge já feito")


display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
#Nesse bloco ficara a análise da quantidade de compras por cliente para entendermos qual o melhor cliente

frequencia_clientes = vendas_df['E-mail do Cliente'].value_counts()
display(frequencia_clientes)

frequencia_clientes[:10].plot.bar(xlabel = 'E-mail do Cliente', ylabel ='Quantidade de Compras', figsize=(15,5), title = 'Frequência de Compras',
                                  legend = True, yticks = range(0, 100 , 10))
# Out:
# E-mail do Cliente
# karen33@adventure-works.com      77
# chloe77@adventure-works.com      74
# julia43@adventure-works.com      69
# gilbert9@adventure-works.com     68
# destiny66@adventure-works.com    68
#                                  ..
# mblemen9o@ebay.com                1
# rebecca15@adventure-works.com     1
# kevin10@adventure-works.com       1
# siliffe8l@spotify.com             1
# clifford8@adventure-works.com     1
# Name: count, Length: 38907, dtype: int64
# <Axes: title={'center': 'Frequência de Compras'}, xlabel='E-mail do Cliente', ylabel='Quantidade de Compras'>
